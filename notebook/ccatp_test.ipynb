# %%
import matplotlib.pyplot as plt
import limpy.lcp as ll

# %%
boxsize=500  # Size of the box in comoving Mpc (cMpc)
ngrid= 2048 # number of grids along the box axis
nproj=10    # no of cells to project
halo_redshift=5.8 # redshift of halos, (Note: at this point it is not used in the function)

#It can read halos and density only from the redshift information but now, lets just do it for one redshift 
# by manually providng the files

#location of density file
root='/Volumes/Maxtor/density_halos/'
#root1="/Users/anirbanroy/Documents/21cmFAST/Output_files/Halo_lists/"

#dens_file=root+'updated_smoothed_deltax_z00%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

#location of halo catalogue file

halocat_file=root+'halos_z%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

# %%
# plot CII luminosity using beam convolution. 
# Use_scatter= True

beam_fwhm=57 
beam_unit='arcsec'
ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift, 
          halo_cutoff_mass=1e11, use_scatter=True, unit='degree', halocat_file_type='npz', add_noise=False, random_noise_parcentage=None)

plt.savefig("CII_z%1.2f_L80N512_f200_mmin1e11.pdf" %(halo_redshift))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-42d328c24660> in <module>
#       5 beam_unit='arcsec'
#       6 ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift,
# ----> 7           halo_cutoff_mass=1e11, use_scatter=True, unit='degree', halocat_file_type='npz', add_noise=False, random_noise_parcentage=None)
#       8
#       9 plt.savefig("CII_z%1.2f_L80N512_f200_mmin1e11.pdf" %(halo_redshift))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/limpy-1.0-py3.7.egg/limpy/lcp.py in plot_beam(theta_fwhm, beam_unit, boxsize, ngrid, nproj, halocat_file, halo_redshift, halo_cutoff_mass, use_scatter, halocat_file_type, unit, plot_unit, tick_num, add_noise, random_noise_parcentage)
#     695
#     696     xl, yl, lum=calc_luminosity(boxsize, ngrid, nproj,halocat_file, halo_redshift,
# --> 697                                 halo_cutoff_mass=halo_cutoff_mass, use_scatter=use_scatter, unit=unit)
#     698
#     699     if(beam_unit=='arcmin' or beam_unit=='arcminute' or beam_unit=='minute'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/limpy-1.0-py3.7.egg/limpy/lcp.py in calc_luminosity(boxsize, ngrid, nproj, halocat_file, halo_redshift, halo_cutoff_mass, use_scatter, halocat_file_type, unit)
#     333     cellsize = boxsize/ngrid
#     334
# --> 335     halomass, halo_cm=make_halocat(halocat_file,filetype=halocat_file_type,boxsize=boxsize)
#     336
#     337     nhalo=len(halomass)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/limpy-1.0-py3.7.egg/limpy/lcp.py in make_halocat(halo_file, filetype, boxsize)
#      84     """
#      85     if filetype=='npz':
# ---> 86         fn=np.load(halo_file)
#      87         #halomass and x,y,z are read in the following format
#      88         halomass, halo_x, halo_y, halo_z = fn['m'], fn['x'],fn['y'],fn['z']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     455             # Try a pickle
#     456             if not allow_pickle:
# --> 457                 raise ValueError("Cannot load file containing pickled data "
#     458                                  "when allow_pickle=False")
#     459             try:
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
boxsize=80  # Size of the box in comoving Mpc (cMpc)
ngrid= 512  # number of grids along the box axis
nproj=10    # no of cells to project
halo_redshift=5.8 # redshift of halos, (Note: at this point it is not used in the function)

#It can read halos and density only from the redshift information but now, lets just do it for one redshift 
# by manually providng the files

#location of density file
root="/Users/anirbanroy/Documents/21cmFAST/Boxes/"
root1="/Users/anirbanroy/Documents/21cmFAST/Output_files/Halo_lists/"

dens_file=root+'updated_smoothed_deltax_z00%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

#location of halo catalogue file

halocat_file=root1+'halos_z%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

# %%
# plot CII luminosity using beam convolution. 
# Use_scatter= True

beam_fwhm=200 
beam_unit='arcsec'
ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift, 
          halo_cutoff_mass=1e11, use_scatter=True, unit='degree', add_noise=False, random_noise_parcentage=None)

plt.savefig("CII_z%1.2f_L80N512_f200_mmin1e11.pdf" %(halo_redshift))
# Out:
# Minimum halo mass: 336666900.0
# Maximum halo mass: 1788722000000.0
# [2.15108894e+08 1.27755232e+09 3.92513819e+08 2.05147691e+08
#  5.02944652e+08 1.47284095e+08 2.31668423e+08 2.93934992e+08
#  2.53355437e+08 2.15850008e+08 1.12899428e+08 2.56814964e+08
#  8.29659862e+07 1.49267424e+08 1.05804725e+08 1.27682305e+08
#  9.39907520e+07 2.01883666e+08 1.16825923e+08 4.86947069e+07
#  5.66268935e+07 8.96406830e+07 1.28121815e+08 5.57931837e+07
#  6.28587209e+07 1.16015229e+08]
# Theta FWHM (arc-second): 57

# %%
# plot CII luminosity using beam convolution. 
# Use_scatter= True

beam_fwhm=57 
beam_unit='arcsec'
ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift, 
          halo_cutoff_mass_log=11, use_scatter=True, unit='degree', add_noise=False, random_noise_parcentage=None)

plt.savefig("CII_z%1.2f_L80N512_f57_mmin1e11.pdf" %(halo_redshift))
# Out:
# Minimum halo mass: 336666900.0
# Maximum halo mass: 1788722000000.0
# Theta FWHM (arc-second): 57

# %%
boxsize=500  # Size of the box in comoving Mpc (cMpc)
ngrid= 2048 # number of grids along the box axis
nproj=1    # no of cells to project
halo_redshift=7.6 # redshift of halos, (Note: at this point it is not used in the function)

#It can read halos and density only from the redshift information but now, lets just do it for one redshift 
# by manually providng the files

#location of density file
root="/Volumes/Maxtor/density_halos/"

dens_file=root+'updated_smoothed_deltax_z00%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

#location of halo catalogue file

halocat_file=root+'halos_z%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

# %%
# plot CII luminosity using beam convolution. 
# Use_scatter= True

beam_fwhm=57 
beam_unit='arcsec'
ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift, 
          halo_cutoff_mass_log=11, use_scatter=True, unit='degree', add_noise=False, random_noise_parcentage=None)

plt.savefig("CII_z%1.2f_L500N2048_f57.pdf" %(halo_redshift))

# %%
# plot CII luminosity using beam convolution. 
# Use_scatter= False

boxsize=80  # Size of the box in comoving Mpc (cMpc)
ngrid= 512  # number of grids along the box axis
nproj=10    # no of cells to project
halo_redshift=3.6 # redshift of halos, (Note: at this point it is not used in the function)

#It can read halos and density only from the redshift information but now, lets just do it for one redshift 
# by manually providng the files

#location of density file
root="/Users/anirbanroy/Documents/21cmFAST/Boxes/"
root1="/Users/anirbanroy/Documents/21cmFAST/Output_files/Halo_lists/"

dens_file=root+'updated_smoothed_deltax_z00%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

#location of halo catalogue file

halocat_file=root1+'halos_z%1.2f_%d_%dMpc' %(halo_redshift, ngrid,boxsize)

beam_fwhm=57 
beam_unit='arcsec'
ll.plot_beam(57,'arcsec', boxsize, ngrid, nproj, halocat_file, halo_redshift, 
          halo_cutoff_mass_log=11, use_scatter=False, unit='degree', add_noise=False, random_noise_parcentage=None)
# Out:
# Minimum halo mass: 336666900.0
# Maximum halo mass: 7471935000000.0
# Theta FWHM (arc-second): 57
